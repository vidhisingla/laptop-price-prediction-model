# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/AI classes/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
#UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 131543: invalid continuation byte

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample()
# Out:
#     Company          Product   TypeName  Inches  \
# 146      HP  EliteBook Folio  Ultrabook    12.5
#
#                                   ScreenResolution                       Cpu  \
# 146  IPS Panel 4K Ultra HD / Touchscreen 3840x2160  Intel Core M 6Y75 1.2GHz
#
#      Ram     Memory                    Gpu       OpSys  Weight  Price_euros
# 146  8GB  512GB SSD  Intel HD Graphics 515  Windows 10  0.97kg       2014.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1275, 12)

# %%
df.sample()
# Out:
#      Company                             Product  TypeName  Inches  \
# 1151      HP  15-BA015wm (E2-7110/4GB/500GB/W10)  Notebook    15.6
#
#      ScreenResolution                       Cpu  Ram     Memory  \
# 1151         1366x768  AMD E-Series 7110 1.8GHz  4GB  500GB HDD
#
#                          Gpu       OpSys  Weight  Price_euros
# 1151  AMD Radeon R2 Graphics  Windows 10  1.86kg        297.0

# %%
df['Price']=(df['Price_euros']*90.96).astype('int')
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample()
# Out:
#     Company         Product  TypeName  Inches   ScreenResolution  \
# 708  Lenovo  Thinkpad T460p  Notebook    14.0  Full HD 1920x1080
#
#                              Cpu  Ram     Memory                    Gpu  \
# 708  Intel Core i5 6300HQ 2.3GHz  8GB  256GB SSD  Intel HD Graphics 520
#
#           OpSys Weight   Price
# 708  Windows 10  1.8kg  108333

# %%
#EDA
#- univariate analysis
#- multivariate analysis

# %%
#company column
df['Company'].value_counts() #ek company ka name kitni baar appear hua
# Out:
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
plt.rcParams['figure.figsize']=[6,4]

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df=df[df.groupby('Company').Company.transform('count')>10].copy()

# %%
df.shape
# Out:
# (1224, 12)

# %%
df=df.reset_index(drop=True)

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Product'].value_counts()
# Out:
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: Product, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution                         Cpu  \
# 354      HP  Notebook    15.6  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
#
#      Ram   Memory                    Gpu       OpSys  Weight  Price
# 354  8GB  1TB HDD  Intel HD Graphics 620  Windows 10  1.86kg  58123

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: TypeName, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: Inches, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.displot(x=df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                 ScreenResolution  \
# 911    Dell  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
#
#                            Cpu  Ram     Memory                    Gpu  \
# 911  Intel Core i5 7Y54 1.2GHz  8GB  256GB SSD  Intel HD Graphics 615
#
#           OpSys  Weight   Price
# 911  Windows 10  1.24kg  172733

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# ...

# %%
#x_res : horizontal pixels
#y_res : verticle pixels
#IPS : IPS panel or not
#touchscreen : touchscreen or not

# %%
a="IPS Panel 4K Ultra HD 3840x2160 "

# %%
a.split()
# Out:
# ['IPS', 'Panel', '4K', 'Ultra', 'HD', '3840x2160']

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split('x')
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0] #x_res
# Out:
# '3840'

# %%
(lambda x:x.split()[-1].split('x')[0])("IPS Panel 4K Ultra HD 3840x2160 ")
# Out:
# '3840'

# %%
(lambda x:x.split()[-1].split('x')[1])("IPS Panel 4K Ultra HD 3840x2160 ")
# Out:
# '2160'

# %%
(lambda x:1 if "Touchscreen" in x else 0)("IPS Panel / 4K Ultra HD 3840x2160 ")
# Out:
# 0

# %%
df['x_res']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[0]).astype('int')

# %%
df['y_res']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[1]).astype('int')

# %%
df['touchscreen']=df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0).astype('int')
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0).astype('int')

# %%
df.sample(7)
# Out:
#      Company            TypeName  Inches             ScreenResolution  \
# 1045    Asus              Gaming    17.3  IPS Panel Full HD 1920x1080
# 46      Asus              Gaming    17.3            Full HD 1920x1080
# 1110      HP  2 in 1 Convertible    13.3        Touchscreen 2560x1440
# 760     Dell            Notebook    15.6                     1366x768
# 1212    Acer            Notebook    15.6                     1366x768
# 1123    Asus            Notebook    15.6                     1366x768
# 399   Lenovo            Notebook    15.6            Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 1045           Intel Core i7 7700HQ 2.8GHz  8GB  256GB SSD +  1TB HDD
# 46                     AMD Ryzen 1700 3GHz  8GB  256GB SSD +  1TB HDD
# 1110            Intel Core i7 6600U 2.6GHz  8GB             512GB SSD
# 760             Intel Core i5 7200U 2.5GHz  8GB             128GB SSD
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches                         Cpu  Ram     Memory  \
# 977      HP  Notebook    14.0  Intel Core i7 7500U 2.7GHz  8GB  256GB SSD
#
#                       Gpu       OpSys  Weight   Price  x_res  y_res  \
# 977  Nvidia GeForce 930MX  Windows 10  1.64kg  107826   1920   1080
#
#      touchscreen  IPS
# 977            0    0

# %%
df['Ram'].value_counts()
# Out:
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: Ram, dtype: int64

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: Cpu, Length: 111, dtype: int64

# %%
a="Intel Core i5 8250U 1.6GHz"

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda a:" ".join(a.split()[0:3]))("Intel Core i5 8250U 1.6GHz")
# Out:
# 'Intel Core i5'

# %%
df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# ...

# %%
def fetch_name(text):
  if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3' or text=='Intel Core M':
    return text
  elif text.split()[0]=='Intel':
    return " ".join(text.split()[0:2])
  else:
    return "AMD Processor"

# %%
df['Cpu']=df['Cpu'].apply(fetch_name)

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i7    493
# Intel Core i5    411
# Intel Core i3    134
# Intel Celeron     71
# AMD Processor     60
# Intel Pentium     30
# Intel Core M      16
# Intel Atom         5
# Intel Xeon         4
# Name: Cpu, dtype: int64

# %%
df.sample()
# Out:
#     Company TypeName  Inches            Cpu  Ram                Memory  \
# 392    Asus   Gaming    17.3  Intel Core i7   16  256GB SSD +  1TB HDD
#
#                          Gpu       OpSys Weight   Price  x_res  y_res  \
# 392  Nvidia GeForce GTX 1050  Windows 10  2.9kg  139077   1920   1080
#
#      touchscreen  IPS
# 392            0    0

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Cpu'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# ...

# %%
#due to complexity skip the memory col :)

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample()
# Out:
#     Company            TypeName  Inches            Cpu  Ram  \
# 648      HP  2 in 1 Convertible    11.6  Intel Celeron    8
#
#                        Gpu      OpSys Weight  Price  x_res  y_res  \
# 648  Intel HD Graphics 500  Chrome OS  1.4kg  45025   1366    768
#
#      touchscreen  IPS
# 648            1    0

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: Gpu, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Intel     666
# Nvidia    385
# AMD       173
# Name: Gpu, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Gpu'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: OpSys, dtype: int64

# %%
def fetch_os(text):
  if text=='Windows 10' or text=='Windows 10 S':
    return "Windows 10"
  elif text=="Windows 7":
    return text
  elif text=='Mac OS X' or text=='macOS':
    return "Mac OS"
  else:
    return 'Linux/no OS/Others'

# %%
df['OpSys']=df['OpSys'].apply(fetch_os)

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10            1013
# Linux/no OS/Others     145
# Windows 7               45
# Mac OS                  21
# Name: OpSys, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight'].value_counts()
# Out:
# 2.2kg     115
# 2.1kg      58
# 2.4kg      42
# 2.5kg      37
# 2.3kg      36
#          ...
# 1.71kg      1
# 0.98kg      1
# 4.7kg       1
# 1.55kg      1
# 4.0kg       1
# Name: Weight, Length: 175, dtype: int64

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
sns.displot(x=df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram    Gpu       OpSys  Weight  \
# 885  Lenovo  Notebook    15.6  Intel Pentium    4  Intel  Windows 10     2.2
#
#      Price  x_res  y_res  touchscreen  IPS
# 885  28106   1366    768            0    0

# %%
df['touchscreen'].value_counts()
# Out:
# 0    1055
# 1     169
# Name: touchscreen, dtype: int64

# %%
df['touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['touchscreen'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS'].value_counts()
# Out:
# 0    885
# 1    339
# Name: IPS, dtype: int64

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['IPS'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df.corr(numeric_only=True) #correlation
# Out:
#                Inches       Ram    Weight     Price     x_res     y_res  \
# Inches       1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram          0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight       0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price        0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# x_res       -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# y_res       -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# touchscreen -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# IPS         -0.104090  0.223322  0.038753  0.289226  0.283969  0.294360
#
#              touchscreen       IPS
# Inches         -0.359497 -0.104090
# Ram             0.094037  0.223322
# Weight         -0.291506  0.038753
# Price           0.161443  0.289226
# x_res           0.320954  0.283969
# y_res           0.317174  0.294360
# touchscreen     1.000000  0.154500
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# x_res          0.553707
# y_res          0.552964
# touchscreen    0.161443
# IPS            0.289226
# Name: Price, dtype: float64

# %%
#ram has strong corr with price uske baad its x  n y resolution
#but x n y res is defined by inches
#better is ppi=pixels per inch (pixel density). better measure

# %%
df['ppi']=round(((df['x_res']**2)+(df['y_res']**2))**0.5/df['Inches']).astype('int')

# %%
df['ppi']
# Out:
# 0       227
# 1       128
# 2       141
# 3       221
# 4       227
#        ...
# 1219    157
# 1220    276
# 1221    112
# 1222    100
# 1223    100
# Name: ppi, Length: 1224, dtype: int64

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# x_res          0.553707
# y_res          0.552964
# touchscreen    0.161443
# IPS            0.289226
# ppi            0.483821
# Name: Price, dtype: float64

# %%
#ppi eleminates x_res, y_res n inches

# %%
df.drop(columns=['Inches','x_res','y_res'],inplace=True)

# %%
df.sample()
# Out:
#    Company  TypeName            Cpu  Ram  Gpu       OpSys  Weight  Price  \
# 98      HP  Notebook  Intel Core i7    8  AMD  Windows 10    1.91  65400
#
#     touchscreen  IPS  ppi
# 98            0    0  141

# %%
df['ppi'].value_counts()
# Out:
# 141    419
# 100    195
# 127    131
# 157    122
# 166    100
# 112     42
# 135     28
# 176     25
# 276     25
# 282     23
# 106     22
# 210     18
# 125      9
# 118      8
# 331      7
# 227      6
# 226      6
# 221      6
# 255      5
# 128      4
# 224      4
# 158      4
# 317      2
# 170      2
# 91       2
# 352      2
# 190      1
# 108      1
# 120      1
# 111      1
# 195      1
# 235      1
# 147      1
# Name: ppi, dtype: int64

# %%
sns.displot(x=df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df.sample()
# Out:
#      Company     TypeName            Cpu  Ram     Gpu      OpSys  Weight  \
# 1094      HP  Workstation  Intel Core i7    8  Nvidia  Windows 7    2.59
#
#        Price  touchscreen  IPS  ppi
# 1094  202749            0    1  141

# %%
df.shape
# Out:
# (1224, 11)

# %%
sns.displot(x=df['Price'],kde=True)
plt.show()

# %%
# we need to make the graph similar to normal dist ka graph
sns.displot(x=np.log(df['Price']),kde=True)
plt.show()

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
x
# Out:
#      Company            TypeName            Cpu  Ram    Gpu  \
# 0      Apple           Ultrabook  Intel Core i5    8  Intel
# 1      Apple           Ultrabook  Intel Core i5    8  Intel
# 2         HP            Notebook  Intel Core i5    8  Intel
# 3      Apple           Ultrabook  Intel Core i7   16    AMD
# 4      Apple           Ultrabook  Intel Core i5    8  Intel
# ...      ...                 ...            ...  ...    ...
# 1219  Lenovo  2 in 1 Convertible  Intel Core i7    4  Intel
# 1220  Lenovo  2 in 1 Convertible  Intel Core i7   16  Intel
# 1221  Lenovo            Notebook  Intel Celeron    2  Intel
# 1222      HP            Notebook  Intel Core i7    6    AMD
# 1223    Asus            Notebook  Intel Celeron    4  Intel
#
#                    OpSys  Weight  touchscreen  IPS  ppi
# 0                 Mac OS    1.37            0    1  227
# 1                 Mac OS    1.34            0    0  128
# 2     Linux/no OS/Others    1.86            0    0  141
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=42)

# %%
x.shape
# Out:
# (1224, 10)

# %%
x_train.shape
# Out:
# (1040, 10)

# %%
x_test.shape
# Out:
# (184, 10)

# %%
x.head()
# Out:
#   Company   TypeName            Cpu  Ram    Gpu               OpSys  Weight  \
# 0   Apple  Ultrabook  Intel Core i5    8  Intel              Mac OS    1.37
# 1   Apple  Ultrabook  Intel Core i5    8  Intel              Mac OS    1.34
# 2      HP   Notebook  Intel Core i5    8  Intel  Linux/no OS/Others    1.86
# 3   Apple  Ultrabook  Intel Core i7   16    AMD              Mac OS    1.83
# 4   Apple  Ultrabook  Intel Core i5    8  Intel              Mac OS    1.37
#
#    touchscreen  IPS  ppi
# 0            0    1  227
# 1            0    0  128
# 2            0    0  141
# 3            0    1  221
# 4            0    1  227

# %%
x_train.head()
# Out:
#     Company   TypeName            Cpu  Ram     Gpu       OpSys  Weight  \
# 240   Apple  Ultrabook  Intel Core i5    8   Intel      Mac OS    1.37
# 439  Lenovo   Notebook  Intel Core i5    8   Intel  Windows 10    1.65
# 192    Dell     Gaming  Intel Core i7   16  Nvidia  Windows 10    2.65
# 218    Asus   Notebook  Intel Core i5    8  Nvidia  Windows 10    2.00
# 184    Dell   Notebook  Intel Core i7    8     AMD  Windows 10    2.80
#
#      touchscreen  IPS  ppi
# 240            0    1  227
# 439            0    0  157
# 192            0    1  282
# 218            0    0  141
# 184            0    0  127

# %%
x_test.head()
# Out:
#     Company            TypeName            Cpu  Ram     Gpu       OpSys  \
# 661  Lenovo            Notebook  Intel Core i5    4   Intel  Windows 10
# 220      HP            Notebook  Intel Core i7    8     AMD  Windows 10
# 155    Dell  2 in 1 Convertible  Intel Core i7    8   Intel  Windows 10
# 677  Lenovo         Workstation  Intel Core i7   16  Nvidia   Windows 7
# 911    Dell  2 in 1 Convertible  Intel Core i5    8   Intel  Windows 10
#
#      Weight  touchscreen  IPS  ppi
# 661    1.70            0    0  157
# 220    1.90            0    0  141
# 155    1.56            1    0  141
# 677    2.18            0    0  141
# 911    1.24            1    0  166

# %%
y_train.head()
# Out:
# 240    12.131123
# 439    11.714568
# 192    12.030653
# 218    11.155507
# 184    11.499749
# Name: Price, dtype: float64

# %%
y_test.head()
# Out:
# 661    11.060070
# 220    11.656402
# 155    11.466012
# 677    12.036055
# 911    12.059502
# Name: Price, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
x_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram    Gpu               OpSys  Weight  \
# 587    Dell  Notebook  Intel Core i3    4  Intel  Linux/no OS/Others    2.18
#
#      touchscreen  IPS  ppi
# 587            0    0  100

# %%
# LinearRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7849854828706778
# MAE: 0.20009186638712761
# MSE: 0.0678906670648767

# %%
#Lasso
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Lasso(alpha=0.001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7924904607933325
# MAE: 0.19507784204024442
# MSE: 0.06552097610503446

# %%
#Ridge
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Ridge(alpha=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7911478899674752
# MAE: 0.19647484813345845
# MSE: 0.06594489180229166

# %%
#KNeighborsRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=KNeighborsRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7859697023952642
# MAE: 0.1926773629893376
# MSE: 0.06757990051313613

# %%
#DecisionTreeRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=7)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8195906778100627
# MAE: 0.1821693987676814
# MSE: 0.056964103595062786

# %%
#SVR ( Support Vector Regressor)
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=SVR(C=10000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8144162220880313
# MAE: 0.1811312900754648
# MSE: 0.05859793397710663

# %%
#RandomForestRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8645268908580064
# MAE: 0.15800832617398203
# MSE: 0.04277552916797227

# %%
#AdaBoostRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=AdaBoostRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8005225952151334
# MAE: 0.2037083322598887
# MSE: 0.06298483588933529

# %%
# eXtreme Gradient Boossting Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=XGBRegressor(n_estimators=50,max_depth=4)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.887153320268592
# MAE: 0.1434367063159909
# MSE: 0.03563125162573967

# %%
#so out of all gradient boost n extreme gradient boost are best but XGBRegressor
#is an external algo n this takes up more resources(so shift it to bottom causse pipe overwrites)

# %%
#GradientBoostingRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=200)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8796905957659243
# MAE: 0.14537126589736563
# MSE: 0.0379876011009836

# %%
import pickle
pickle.dump(df,open('df.pkl','wb')) #wb=write block it'll write df in df.pkl rb=read block
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 31.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 78.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 32.4 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))

st.title("Laptop price predictor")
company=st.selectbox("Brand",df['Company'].unique(),index=4)
type=st.selectbox("Type",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
ram=st.selectbox("RAM(in GB)",[2,4,6,8,12,16,24,32,64,128],index=3)
gpu=st.selectbox("GPU",df['Gpu'].unique(),index=0)
# Out:
# Overwriting app.py

# %%
# above company mei index=4 means look at list below dell has 4th index so it is default value

# %%
x_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram  Gpu       OpSys  Weight  \
# 304    Acer  Notebook  AMD Processor    8  AMD  Windows 10    2.23
#
#      touchscreen  IPS  ppi
# 304            0    0  141

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'MSI', 'Toshiba'],
#       dtype=object)

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df['Cpu'].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD Processor', 'Intel Core i3',
#        'Intel Core M', 'Intel Atom', 'Intel Celeron', 'Intel Pentium',
#        'Intel Xeon'], dtype=object)

# %%
df['Ram'].unique()
# Out:
# array([ 8, 16,  4,  2, 12,  6, 32, 24, 64])

# %%
df['Gpu'].unique()
# Out:
# array(['Intel', 'AMD', 'Nvidia'], dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] | fetchMetadata: sill resolveWithNewModule localtunnel@2.0
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.141.151.131:8501
#
# npx: installed 22 in 7.235s
# your url is: https://good-moose-sip.loca.lt
#   Stopping...
# ^C
